# %%
from PipelineFunctionsClassification import *
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import make_column_transformer

# %% [markdown]
# # 1.0 Diabetic Retinopathy Dataset

# %%
data_arff = load_arff_file("./data/messidor_features.arff",data_type='float64',delimiter_used=',',skip_rows=24,use_cols=None)
X,y = split_data(data_arff,19,1)
X_trn, X_tst, y_trn, y_tst = preprocess(X,y)

# %%
train_all_classifiers(X_trn,y_trn,X_tst,y_tst)
# Out:
# Dummy model: LogisticRegression()
# With 73.913% train accuracy
# With 70.231% test accuracy
#
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# Best estimator: LogisticRegression(C=10.0, max_iter=10000, random_state=0, solver='newton-cg')
# With 75.901% train accuracy
# With 73.41% test accuracy
#
# Dummy model: SVC()
# With 74.658% train accuracy
# With 66.474% test accuracy
#
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best estimator: SVC(C=100.0, gamma=0.01, random_state=0)
# With 80.621% train accuracy
# With 73.121% test accuracy
#
# Dummy model: DecisionTreeClassifier()
# With 100.0% train accuracy
# With 54.335% test accuracy
#
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# Best estimator: DecisionTreeClassifier(max_depth=5, min_samples_leaf=50, random_state=0)
# With 69.814% train accuracy
# With 63.584% test accuracy
#
# Dummy model: RandomForestClassifier()
# With 100.0% train accuracy
# With 67.052% test accuracy
#
# Fitting 3 folds for each of 56 candidates, totalling 168 fits
# Best estimator: RandomForestClassifier(max_depth=10, n_estimators=250, random_state=0)
# With 94.534% train accuracy
# With 67.341% test accuracy
#
# Dummy model: KNeighborsClassifier()
# With 74.286% train accuracy
# With 61.85% test accuracy
#
# Fitting 3 folds for each of 45 candidates, totalling 135 fits
# Best estimator: KNeighborsClassifier(metric='manhattan', n_neighbors=29)
# With 68.447% train accuracy
# With 66.763% test accuracy
#
# Dummy model: AdaBoostClassifier()
# With 76.77% train accuracy
# With 68.497% test accuracy
#
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best estimator: AdaBoostClassifier(algorithm='SAMME', learning_rate=1.5, n_estimators=80,
#                    random_state=0)
# With 79.503% train accuracy
# With 67.341% test accuracy
#
# Dummy model: GaussianNB()
# With 63.106% train accuracy
# With 45.087% test accuracy
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Best estimator: GaussianNB(var_smoothing=1e-08)
# With 64.348% train accuracy
# With 45.087% test accuracy
# /Users/davidrady/Desktop/COMP432-MLProject/classification/PipelineFunctionsClassification.py:98: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(14, 4))
# Dummy model: MLPClassifier()
# With 76.894% train accuracy
# With 69.364% test accuracy
#
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best estimator: MLPClassifier(batch_size=100, hidden_layer_sizes=(10,), learning_rate_init=0.01,
#               max_iter=1000, random_state=0, solver='sgd')
# With 78.137% train accuracy
# With 73.41% test accuracy

# %% [markdown]
# # 2.0 Default Credit Dataset

# %%
data_xls = load_xls_file("./data/default of credit card clients.xls",2,1)
X,y = split_data(data_xls,23,1)
y = y.astype(np.int32)
X_trn, X_tst, y_trn, y_tst = preprocess(X,y)

# %%
train_all_classifiers(X_trn,y_trn,X_tst,y_tst)
# Out:
# Dummy model: LogisticRegression()
# With 80.767% train accuracy
# With 81.8% test accuracy
#
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# Best estimator: LogisticRegression(C=0.0001, max_iter=10000, random_state=0, solver='liblinear')
# With 80.933% train accuracy
# With 81.078% test accuracy
#
# Dummy model: SVC()
# With 82.329% train accuracy
# With 82.267% test accuracy
#
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best estimator: SVC(C=10.0, gamma=0.01, random_state=0)
# With 82.114% train accuracy
# With 82.344% test accuracy
#
# Dummy model: DecisionTreeClassifier()
# With 99.971% train accuracy
# With 71.678% test accuracy
#
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# Best estimator: DecisionTreeClassifier(max_depth=5, min_samples_leaf=25, random_state=0)
# With 82.262% train accuracy
# With 82.211% test accuracy
#
# Dummy model: RandomForestClassifier()
# With 99.971% train accuracy
# With 82.122% test accuracy
#
# Fitting 3 folds for each of 56 candidates, totalling 168 fits
# Best estimator: RandomForestClassifier(max_depth=10, random_state=0)
# With 85.79% train accuracy
# With 82.378% test accuracy
#
# Dummy model: KNeighborsClassifier()
# With 84.276% train accuracy
# With 78.933% test accuracy
#
# Fitting 3 folds for each of 45 candidates, totalling 135 fits
# Best estimator: KNeighborsClassifier(metric='euclidean', n_neighbors=19)
# With 82.124% train accuracy
# With 81.022% test accuracy
#
# Dummy model: AdaBoostClassifier()
# With 81.757% train accuracy
# With 82.011% test accuracy
#
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best estimator: AdaBoostClassifier(algorithm='SAMME', n_estimators=25, random_state=0)
# With 81.662% train accuracy
# With 82.478% test accuracy
#
# Dummy model: GaussianNB()
# With 58.81% train accuracy
# With 56.756% test accuracy
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Best estimator: GaussianNB(var_smoothing=1.0)
# With 79.876% train accuracy
# With 80.144% test accuracy
# /Users/davidrady/Desktop/COMP432-MLProject/classification/PipelineFunctionsClassification.py:98: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(14, 4))
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Dummy model: MLPClassifier()
# With 83.371% train accuracy
# With 81.378% test accuracy
#
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best estimator: MLPClassifier(batch_size=100, hidden_layer_sizes=(10,), learning_rate_init=0.01,
#               max_iter=1000, random_state=0, solver='sgd')
# With 82.062% train accuracy
# With 82.111% test accuracy

# %% [markdown]
# # 3.0 Breast Cancer Dataset

# %%
# Load the data and split into features and targets, X and y
# This data is not loaded using a predefined function since it contains strings as targets, so it is dealt with differently
cols = np.arange(2,32)
X = np.loadtxt("./data/wdbc.data",usecols=cols,delimiter=',') 
y = np.loadtxt("./data/wdbc.data",dtype=str,usecols=1,delimiter=',')

# Assign 'M' (Malignant) a value 1, and 'B' (Benign) a value 0
for i in range(len(y)):
    if y[i] == 'M':
        y[i] = 1
    else: 
        y[i] = 0
        
X_trn, X_tst, y_trn, y_tst = preprocess(X,y)

# %%
train_all_classifiers(X_trn,y_trn,X_tst,y_tst)
# Out:
# Dummy model: LogisticRegression()
# With 98.995% train accuracy
# With 96.491% test accuracy
#
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# Best estimator: LogisticRegression(max_iter=10000, random_state=0, solver='newton-cg')
# With 98.995% train accuracy
# With 96.491% test accuracy
#
# Dummy model: SVC()
# With 98.241% train accuracy
# With 97.661% test accuracy
#
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best estimator: SVC(C=10.0, gamma=0.01, random_state=0)
# With 98.492% train accuracy
# With 98.246% test accuracy
#
# Dummy model: DecisionTreeClassifier()
# With 100.0% train accuracy
# With 90.643% test accuracy
#
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# Best estimator: DecisionTreeClassifier(max_depth=5, min_samples_leaf=5, random_state=0)
# With 96.231% train accuracy
# With 94.152% test accuracy
#
# Dummy model: RandomForestClassifier()
# With 100.0% train accuracy
# With 96.491% test accuracy
#
# Fitting 3 folds for each of 56 candidates, totalling 168 fits
# Best estimator: RandomForestClassifier(max_depth=10, n_estimators=250, random_state=0)
# With 100.0% train accuracy
# With 97.076% test accuracy
#
# Dummy model: KNeighborsClassifier()
# With 97.236% train accuracy
# With 94.737% test accuracy
#
# Fitting 3 folds for each of 45 candidates, totalling 135 fits
# Best estimator: KNeighborsClassifier(metric='manhattan', n_neighbors=7)
# With 96.985% train accuracy
# With 95.322% test accuracy
#
# Dummy model: AdaBoostClassifier()
# With 100.0% train accuracy
# With 95.322% test accuracy
#
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best estimator: AdaBoostClassifier(algorithm='SAMME', random_state=0)
# With 100.0% train accuracy
# With 97.661% test accuracy
#
# Dummy model: GaussianNB()
# With 94.221% train accuracy
# With 91.228% test accuracy
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Best estimator: GaussianNB(var_smoothing=0.01)
# With 94.724% train accuracy
# With 91.813% test accuracy
# /Users/davidrady/Desktop/COMP432-MLProject/classification/PipelineFunctionsClassification.py:98: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(14, 4))
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Dummy model: MLPClassifier()
# With 98.995% train accuracy
# With 96.491% test accuracy
#
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best estimator: MLPClassifier(batch_size=100, hidden_layer_sizes=(), learning_rate_init=0.01,
#               max_iter=1000, random_state=0)
# With 98.995% train accuracy
# With 94.737% test accuracy

# %% [markdown]
# # 4.0 Statlog German Credit Dataset

# %%
# Load the data and split into features and targets, X and y
data = np.loadtxt("./data/german.data-numeric",dtype='float64')
X, y = split_data(data,24,1)
X_trn, X_tst, y_trn, y_tst = preprocess(X,y)

# %%
train_all_classifiers(X_trn,y_trn,X_tst,y_tst)
# Out:
# Dummy model: LogisticRegression()
# With 79.0% train accuracy
# With 78.0% test accuracy
#
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# Best estimator: LogisticRegression(C=0.01, max_iter=10000, random_state=0, solver='liblinear')
# With 79.0% train accuracy
# With 77.333% test accuracy
#
# Dummy model: SVC()
# With 87.429% train accuracy
# With 76.667% test accuracy
#
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best estimator: SVC(C=100.0, gamma=0.001, random_state=0)
# With 80.714% train accuracy
# With 77.667% test accuracy
#
# Dummy model: DecisionTreeClassifier()
# With 100.0% train accuracy
# With 66.0% test accuracy
#
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# Best estimator: DecisionTreeClassifier(max_depth=5, min_samples_leaf=10, random_state=0)
# With 78.857% train accuracy
# With 71.333% test accuracy
#
# Dummy model: RandomForestClassifier()
# With 100.0% train accuracy
# With 77.333% test accuracy
#
# Fitting 3 folds for each of 56 candidates, totalling 168 fits
# Best estimator: RandomForestClassifier(max_depth=10, random_state=0)
# With 97.714% train accuracy
# With 75.333% test accuracy
#
# Dummy model: KNeighborsClassifier()
# With 81.571% train accuracy
# With 72.667% test accuracy
#
# Fitting 3 folds for each of 45 candidates, totalling 135 fits
# Best estimator: KNeighborsClassifier(metric='euclidean', n_neighbors=17)
# With 77.0% train accuracy
# With 73.0% test accuracy
#
# Dummy model: AdaBoostClassifier()
# With 80.0% train accuracy
# With 78.0% test accuracy
#
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best estimator: AdaBoostClassifier(algorithm='SAMME', learning_rate=0.5, random_state=0)
# With 76.714% train accuracy
# With 75.667% test accuracy
#
# Dummy model: GaussianNB()
# With 72.714% train accuracy
# With 70.333% test accuracy
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Best estimator: GaussianNB(var_smoothing=1.0)
# With 74.714% train accuracy
# With 75.667% test accuracy
# /Users/davidrady/Desktop/COMP432-MLProject/classification/PipelineFunctionsClassification.py:98: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(14, 4))
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Dummy model: MLPClassifier()
# With 95.0% train accuracy
# With 76.0% test accuracy
#
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Best estimator: MLPClassifier(batch_size=100, hidden_layer_sizes=(), learning_rate_init=0.01,
#               max_iter=1000, random_state=0, solver='sgd')
# With 78.571% train accuracy
# With 78.333% test accuracy

# %% [markdown]
# # 5.0 Adult Dataset

# %%
df_adult = pd.read_csv('data/adult.data', names=['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status', 'occupation', 'relationship','race', 'sex', 'capital_gain', 'capital_loss', 'hours_per_week', 'native_country', 'salary'])
df_adult_test = pd.read_csv('data/adult.test',skiprows=1, names=['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status', 'occupation', 'relationship','race', 'sex', 'capital_gain', 'capital_loss', 'hours_per_week', 'native_country', 'salary'])

# Drop education column since its the same data as education_num
df_adult_clean = df_adult.drop('education', axis=1)
df_adult_test_clean = df_adult_test.drop('education', axis=1)

cat_col = df_adult_clean.select_dtypes(['object']).columns
cat_col_test = df_adult_test_clean.select_dtypes(['object']).columns

df_adult_clean[cat_col] = df_adult_clean[cat_col].apply(lambda x: pd.factorize(x)[0])
df_adult_test_clean[cat_col_test] = df_adult_test_clean[cat_col_test].apply(lambda x: pd.factorize(x)[0])

data_trn = df_adult_clean.to_numpy()
data_tst = df_adult_test_clean.to_numpy()

# We don't preprocess the data for this data set because:
    # 1 - The dataset comes with a test set so no need to train_test_split
    # 2 - Most of the features are categorical instead of numerical, and thus don't require scaling
X_trn, y_trn = split_data(data_trn,13,target_location=1)
X_tst, y_tst = split_data(data_tst,13,target_location=1)

# %%
train_all_classifiers(X_trn,y_trn,X_tst,y_tst)
# Out:
# Dummy model: LogisticRegression()
# With 79.577% train accuracy
# With 79.78% test accuracy
#
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/optimize.py:195: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:437: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/optimize.py:195: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:437: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/optimize.py:195: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:437: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/optimize.py:195: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:437: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/optimize.py:195: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:437: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/optimize.py:195: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:437: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/optimize.py:195: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:437: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/optimize.py:195: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:437: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/optimize.py:195: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:437: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/optimize.py:195: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:437: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/optimize.py:195: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:437: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/optimize.py:195: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:437: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/optimize.py:195: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# ...
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:437: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/optimize.py:195: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:437: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/optimize.py:195: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:437: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/optimize.py:195: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:437: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/optimize.py:195: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')
# Best estimator: LogisticRegression(C=10.0, max_iter=10000, random_state=0, solver='newton-cg')
# With 82.547% train accuracy
# With 81.672% test accuracy
#
# Dummy model: SVC()
# With 79.675% train accuracy
# With 79.903% test accuracy
#
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best estimator: SVC(gamma=0.1, random_state=0)
# With 99.773% train accuracy
# With 76.377% test accuracy
#
# Dummy model: DecisionTreeClassifier()
# With 99.997% train accuracy
# With 77.323% test accuracy
#
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# Best estimator: DecisionTreeClassifier(max_depth=25, min_samples_leaf=50, random_state=0)
# With 86.791% train accuracy
# With 83.472% test accuracy
#
# Dummy model: RandomForestClassifier()
# With 99.997% train accuracy
# With 82.962% test accuracy
#
# Fitting 3 folds for each of 56 candidates, totalling 168 fits
# Best estimator: RandomForestClassifier(max_depth=25, n_estimators=1000, random_state=0)
# With 97.804% train accuracy
# With 83.048% test accuracy
#
# Dummy model: KNeighborsClassifier()
# With 83.649% train accuracy
# With 77.655% test accuracy
#
# Fitting 3 folds for each of 45 candidates, totalling 135 fits
# Best estimator: KNeighborsClassifier(metric='manhattan', n_neighbors=25)
# With 80.498% train accuracy
# With 80.499% test accuracy
#
# Dummy model: AdaBoostClassifier()
# With 85.87% train accuracy
# With 84.374% test accuracy
#
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best estimator: AdaBoostClassifier(algorithm='SAMME', learning_rate=1.5, n_estimators=100,
#                    random_state=0)
# With 85.916% train accuracy
# With 77.919% test accuracy
#
# Dummy model: GaussianNB()
# With 79.549% train accuracy
# With 79.559% test accuracy
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Best estimator: GaussianNB(var_smoothing=1e-05)
# With 80.188% train accuracy
# With 80.216% test accuracy
# /Users/davidrady/Desktop/COMP432-MLProject/classification/PipelineFunctionsClassification.py:98: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(14, 4))
# Dummy model: MLPClassifier()
# With 79.254% train accuracy
# With 79.399% test accuracy
#
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best estimator: MLPClassifier(batch_size=100, hidden_layer_sizes=(100, 100),
#               learning_rate_init=0.01, max_iter=1000, random_state=0)
# With 76.668% train accuracy
# With 77.133% test accuracy

# %% [markdown]
# # 6.0 Yeast Dataset

# %%
data_yeast = np.loadtxt('./data/yeast.data',dtype=str)
X = data_yeast[:,1:-1]
lb_encoder = LabelEncoder()
y = lb_encoder.fit_transform(data_yeast[:,-1])
X_trn, X_tst, y_trn, y_tst = preprocess(X,y)

# %%
train_all_classifiers(X_trn,y_trn,X_tst,y_tst)
# Out:
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Dummy model: LogisticRegression()
# With 60.597% train accuracy
# With 59.417% test accuracy
#
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# Best estimator: LogisticRegression(max_iter=10000, random_state=0, solver='newton-cg')
# With 60.597% train accuracy
# With 59.417% test accuracy
#
# Dummy model: SVC()
# With 64.258% train accuracy
# With 61.435% test accuracy
#
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best estimator: SVC(C=10.0, gamma=0.01, random_state=0)
# With 62.139% train accuracy
# With 58.52% test accuracy
#
# Dummy model: DecisionTreeClassifier()
# With 100.0% train accuracy
# With 52.018% test accuracy
#
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# Best estimator: DecisionTreeClassifier(max_depth=5, min_samples_leaf=5, random_state=0)
# With 62.428% train accuracy
# With 59.641% test accuracy
#
# Dummy model: RandomForestClassifier()
# With 100.0% train accuracy
# With 61.883% test accuracy
#
# Fitting 3 folds for each of 56 candidates, totalling 168 fits
# Best estimator: RandomForestClassifier(max_depth=10, n_estimators=1000, random_state=0)
# With 85.549% train accuracy
# With 64.574% test accuracy
#
# Dummy model: KNeighborsClassifier()
# With 69.75% train accuracy
# With 57.175% test accuracy
#
# Fitting 3 folds for each of 45 candidates, totalling 135 fits
# Best estimator: KNeighborsClassifier(metric='manhattan', n_neighbors=11)
# With 63.873% train accuracy
# With 58.072% test accuracy
#
# Dummy model: AdaBoostClassifier()
# With 33.044% train accuracy
# With 32.96% test accuracy
#
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best estimator: AdaBoostClassifier(algorithm='SAMME', n_estimators=100, random_state=0)
# With 44.99% train accuracy
# With 43.498% test accuracy
#
# Dummy model: GaussianNB()
# With 13.391% train accuracy
# With 17.937% test accuracy
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Best estimator: GaussianNB(var_smoothing=1.0)
# With 57.707% train accuracy
# With 58.296% test accuracy
# /Users/davidrady/Desktop/COMP432-MLProject/classification/PipelineFunctionsClassification.py:98: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(14, 4))
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Dummy model: MLPClassifier()
# With 66.667% train accuracy
# With 61.211% test accuracy
#
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Best estimator: MLPClassifier(batch_size=100, hidden_layer_sizes=(10,), learning_rate_init=0.01,
#               max_iter=1000, random_state=0)
# With 64.355% train accuracy
# With 59.193% test accuracy

# %% [markdown]
# # 7.0 Thoracic Surgery Dataset

# %%
data = np.loadtxt("./data/ThoraricSurgery.arff",dtype=str,skiprows=21, delimiter = ',')

# Account for the categorical data in columns 0,3,9
column_trans = make_column_transformer((OneHotEncoder(),[0,3,9]),remainder='passthrough')
data = column_trans.fit_transform(data)

X, y = split_data(data,16,target_location=1)

# Assign 'T' (True) a value 1, and 'F' (False) a value 0
for i in range(len(y)):
    if y[i] == 'T':
        y[i] = 1
    else: 
        y[i] = 0
X = X.astype(np.float64)
y = y.astype(np.int32)

X_trn, X_tst, y_trn, y_tst = preprocess(X,y)

# %%
train_all_classifiers(X_trn, y_trn, X_tst, y_tst)
# Out:
# Dummy model: LogisticRegression()
# With 93.009% train accuracy
# With 93.617% test accuracy
#
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# Best estimator: LogisticRegression(C=0.0001, max_iter=10000, random_state=0, solver='newton-cg')
# With 93.313% train accuracy
# With 93.617% test accuracy
#
# Dummy model: SVC()
# With 93.921% train accuracy
# With 93.617% test accuracy
#
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best estimator: SVC(C=0.1, gamma=0.001, random_state=0)
# With 93.313% train accuracy
# With 93.617% test accuracy
#
# Dummy model: DecisionTreeClassifier()
# With 100.0% train accuracy
# With 85.106% test accuracy
#
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# Best estimator: DecisionTreeClassifier(max_depth=5, min_samples_leaf=10, random_state=0)
# With 93.313% train accuracy
# With 93.617% test accuracy
#
# Dummy model: RandomForestClassifier()
# With 100.0% train accuracy
# With 94.326% test accuracy
#
# Fitting 3 folds for each of 56 candidates, totalling 168 fits
# Best estimator: RandomForestClassifier(max_depth=10, random_state=0)
# With 97.872% train accuracy
# With 94.326% test accuracy
#
# Dummy model: KNeighborsClassifier()
# With 93.313% train accuracy
# With 93.617% test accuracy
#
# Fitting 3 folds for each of 45 candidates, totalling 135 fits
# Best estimator: KNeighborsClassifier(metric='euclidean')
# With 93.313% train accuracy
# With 93.617% test accuracy
#
# Dummy model: AdaBoostClassifier()
# With 94.529% train accuracy
# With 91.489% test accuracy
#
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best estimator: AdaBoostClassifier(algorithm='SAMME', learning_rate=0.1, n_estimators=25,
#                    random_state=0)
# With 93.313% train accuracy
# With 93.617% test accuracy
#
# Dummy model: GaussianNB()
# With 8.207% train accuracy
# With 93.617% test accuracy
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Best estimator: GaussianNB(var_smoothing=1.0)
# With 87.842% train accuracy
# With 90.071% test accuracy
# /Users/davidrady/Desktop/COMP432-MLProject/classification/PipelineFunctionsClassification.py:98: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(14, 4))
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Dummy model: MLPClassifier()
# With 93.921% train accuracy
# With 93.617% test accuracy
#
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best estimator: MLPClassifier(batch_size=100, hidden_layer_sizes=(10,), learning_rate_init=0.01,
#               max_iter=1000, random_state=0, solver='sgd')
# With 94.225% train accuracy
# With 94.326% test accuracy

# %% [markdown]
# # 8.0 Seismic Bumps Dataset

# %%
data = np.loadtxt("./data/seismic-bumps.arff",dtype=str,delimiter=',', skiprows=154) 
# Account for the categorical data in columns 0,1,2,7
column_trans = make_column_transformer((OneHotEncoder(),[0,1,2,7]),remainder='passthrough')
data = column_trans.fit_transform(data)
X, y = split_data(data,24,target_location=1)
X = X.astype(np.float64)
y = y.astype(np.int32)
X_trn, X_tst, y_trn, y_tst = preprocess(X,y)

# %%
train_all_classifiers(X_trn,y_trn,X_tst,y_tst)
# Out:
# Dummy model: LogisticRegression()
# With 92.588% train accuracy
# With 94.588% test accuracy
#
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# Best estimator: LogisticRegression(C=0.0001, max_iter=10000, random_state=0, solver='newton-cg')
# With 92.865% train accuracy
# With 94.716% test accuracy
#
# Dummy model: SVC()
# With 93.031% train accuracy
# With 94.716% test accuracy
#
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best estimator: SVC(C=0.1, gamma=0.001, random_state=0)
# With 92.865% train accuracy
# With 94.716% test accuracy
#
# Dummy model: DecisionTreeClassifier()
# With 100.0% train accuracy
# With 87.371% test accuracy
#
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# Best estimator: DecisionTreeClassifier(max_depth=5, min_samples_leaf=50, random_state=0)
# With 92.865% train accuracy
# With 94.716% test accuracy
#
# Dummy model: RandomForestClassifier()
# With 100.0% train accuracy
# With 93.943% test accuracy
#
# Fitting 3 folds for each of 56 candidates, totalling 168 fits
# Best estimator: RandomForestClassifier(max_depth=10, n_estimators=250, random_state=0)
# With 96.681% train accuracy
# With 94.201% test accuracy
#
# Dummy model: KNeighborsClassifier()
# With 93.418% train accuracy
# With 93.557% test accuracy
#
# Fitting 3 folds for each of 45 candidates, totalling 135 fits
# Best estimator: KNeighborsClassifier(metric='euclidean', n_neighbors=19)
# With 92.92% train accuracy
# With 94.459% test accuracy
#
# Dummy model: AdaBoostClassifier()
# With 93.086% train accuracy
# With 94.201% test accuracy
#
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best estimator: AdaBoostClassifier(algorithm='SAMME', learning_rate=0.1, n_estimators=1,
#                    random_state=0)
# With 92.865% train accuracy
# With 94.716% test accuracy
#
# Dummy model: GaussianNB()
# With 41.98% train accuracy
# With 94.716% test accuracy
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Best estimator: GaussianNB(var_smoothing=1.0)
# With 87.666% train accuracy
# With 88.918% test accuracy
# /Users/davidrady/Desktop/COMP432-MLProject/classification/PipelineFunctionsClassification.py:98: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(14, 4))
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Dummy model: MLPClassifier()
# With 93.861% train accuracy
# With 94.459% test accuracy
#
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best estimator: MLPClassifier(batch_size=100, hidden_layer_sizes=(), learning_rate_init=0.01,
#               max_iter=1000, random_state=0, solver='sgd')
# With 92.533% train accuracy
# With 94.459% test accuracy

# %% [markdown]
# # Novelty Component - Zoo Animal Classification Dataset

# %%
cols = np.arange(1,18)
data_zoo = np.loadtxt('./data/zoo.csv',dtype='float64',delimiter=',',usecols=cols,skiprows=1)
X,y = split_data(data_zoo,16,1)
X_trn, X_tst, y_trn, y_tst = preprocess(X,y)

# %%
train_all_classifiers(X_trn,y_trn,X_tst,y_tst)
# Out:
# Dummy model: LogisticRegression()
# With 100.0% train accuracy
# With 96.774% test accuracy
#
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# Best estimator: LogisticRegression(max_iter=10000, random_state=0, solver='newton-cg')
# With 100.0% train accuracy
# With 96.774% test accuracy
#
# Dummy model: SVC()
# With 100.0% train accuracy
# With 93.548% test accuracy
#
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best estimator: SVC(C=10.0, gamma=0.01, random_state=0)
# With 100.0% train accuracy
# With 96.774% test accuracy
#
# Dummy model: DecisionTreeClassifier()
# With 100.0% train accuracy
# With 96.774% test accuracy
#
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# Best estimator: DecisionTreeClassifier(max_depth=5, min_samples_leaf=5, random_state=0)
# With 94.286% train accuracy
# With 93.548% test accuracy
#
# Dummy model: RandomForestClassifier()
# With 100.0% train accuracy
# With 96.774% test accuracy
#
# Fitting 3 folds for each of 56 candidates, totalling 168 fits
# Best estimator: RandomForestClassifier(max_depth=10, random_state=0)
# With 100.0% train accuracy
# With 96.774% test accuracy
#
# Dummy model: KNeighborsClassifier()
# With 94.286% train accuracy
# With 100.0% test accuracy
#
# Fitting 3 folds for each of 45 candidates, totalling 135 fits
# Best estimator: KNeighborsClassifier(metric='euclidean', n_neighbors=1)
# With 100.0% train accuracy
# With 96.774% test accuracy
#
# Dummy model: AdaBoostClassifier()
# With 74.286% train accuracy
# With 61.29% test accuracy
#
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best estimator: AdaBoostClassifier(algorithm='SAMME', learning_rate=2.0, n_estimators=85,
#                    random_state=0)
# With 98.571% train accuracy
# With 93.548% test accuracy
#
# Dummy model: GaussianNB()
# With 100.0% train accuracy
# With 90.323% test accuracy
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Best estimator: GaussianNB(var_smoothing=0.1)
# With 100.0% train accuracy
# With 93.548% test accuracy
# /Users/davidrady/Desktop/COMP432-MLProject/classification/PipelineFunctionsClassification.py:98: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(14, 4))
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# Dummy model: MLPClassifier()
# With 100.0% train accuracy
# With 96.774% test accuracy
#
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# /Users/davidrady/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:542: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn("Got `batch_size` less than 1 or larger than "
# Best estimator: MLPClassifier(batch_size=100, learning_rate_init=0.01, max_iter=1000,
#               random_state=0)
# With 100.0% train accuracy
# With 96.774% test accuracy
