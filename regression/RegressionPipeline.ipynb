# %%
from PipelineFunctionsRegression import *
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import make_column_transformer

# %% [markdown]
# ##  1.0 Wine Quality - Red Dataset

# %%
# Load the data and split into features and targets, X and y
rd = pd.read_csv("./data/winequality-red.csv", delimiter = ';')
red_data = rd.to_numpy()
X = red_data[:,:-1]
y = red_data[:,-1:].astype(np.int32).reshape(1599,)

X_trn, X_tst, y_trn, y_tst = preprocess(X,y)
train_all_regressors(X_trn,y_trn,X_tst,y_tst)
# Out:
# Dummy model: LinearRegression()
# With 37.096% train accuracy
# With 31.272% test accuracy
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# Best estimator: LinearRegression(n_jobs=0.0001)
# With 37.096% train accuracy
# With 31.272% test accuracy
# Dummy model: SVR()
# With 56.163% train accuracy
# With 33.478% test accuracy
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# Best estimator: SVR(gamma=0.1)
# With 57.353% train accuracy
# With 33.354% test accuracy
# Dummy model: DecisionTreeRegressor()
# With 100.0% train accuracy
# With -21.469% test accuracy
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# Best estimator: DecisionTreeRegressor(max_depth=5, min_samples_leaf=25, random_state=0)
# With 46.53% train accuracy
# With 17.91% test accuracy
# Dummy model: RandomForestRegressor()
# With 92.998% train accuracy
# With 37.346% test accuracy
# Fitting 3 folds for each of 56 candidates, totalling 168 fits
# Best estimator: RandomForestRegressor(max_depth=50, n_estimators=1000, random_state=0)
# With 93.292% train accuracy
# With 38.44% test accuracy
# Dummy model: KNeighborsRegressor()
# With 56.411% train accuracy
# With 16.257% test accuracy
# Fitting 3 folds for each of 45 candidates, totalling 135 fits
# Best estimator: KNeighborsRegressor(metric='manhattan', n_neighbors=15)
# With 43.969% train accuracy
# With 23.522% test accuracy
# Dummy model: AdaBoostRegressor()
# With 49.422% train accuracy
# With 30.668% test accuracy
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best estimator: AdaBoostRegressor(learning_rate=0.1, n_estimators=80, random_state=0)
# With 45.827% train accuracy
# With 31.136% test accuracy
# Dummy model: GaussianProcessRegressor()
# With 100.0% train accuracy
# With -532.184% test accuracy
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# Best estimator: GaussianProcessRegressor(alpha=0.05)
# With 97.013% train accuracy
# With -538.497% test accuracy
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Dummy model: MLPRegressor()
# With 41.827% train accuracy
# With 8.559% test accuracy
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best estimator: MLPRegressor(batch_size=100, hidden_layer_sizes=(10,), learning_rate_init=0.01,
#              max_iter=1000, random_state=0, solver='sgd')
# With 45.762% train accuracy
# With 29.508% test accuracy

# %% [markdown]
# ##  1.1 Wine Quality - White Dataset

# %%
# Load the data and split into features and targets, X and y
rd = pd.read_csv("./data/winequality-white.csv", delimiter = ';')
red_data = rd.to_numpy()
X = red_data[:,:-1]
y = red_data[:,-1:].astype(np.int32).reshape(4898,)

X_trn, X_tst, y_trn, y_tst = preprocess(X,y)

train_all_regressors(X_trn,y_trn,X_tst,y_tst)
# Out:
# Dummy model: LinearRegression()
# With 29.235% train accuracy
# With 24.63% test accuracy
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# Best estimator: LinearRegression(n_jobs=0.0001)
# With 29.235% train accuracy
# With 24.63% test accuracy
# Dummy model: SVR()
# With 50.48% train accuracy
# With 35.491% test accuracy
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# Best estimator: SVR(gamma=0.1)
# With 51.711% train accuracy
# With 35.72% test accuracy
# Dummy model: DecisionTreeRegressor()
# With 100.0% train accuracy
# With -5.566% test accuracy
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# Best estimator: DecisionTreeRegressor(max_depth=10, min_samples_leaf=50, random_state=0)
# With 41.141% train accuracy
# With 23.368% test accuracy
# Dummy model: RandomForestRegressor()
# With 93.222% train accuracy
# With 42.802% test accuracy
# Fitting 3 folds for each of 56 candidates, totalling 168 fits
# Best estimator: RandomForestRegressor(max_depth=25, n_estimators=500, random_state=0)
# With 93.481% train accuracy
# With 43.985% test accuracy
# Dummy model: KNeighborsRegressor()
# With 58.419% train accuracy
# With 30.163% test accuracy
# Fitting 3 folds for each of 45 candidates, totalling 135 fits
# Best estimator: KNeighborsRegressor(metric='manhattan', n_neighbors=11)
# With 47.53% train accuracy
# With 31.843% test accuracy
# Dummy model: AdaBoostRegressor()
# With 35.828% train accuracy
# With 27.073% test accuracy
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best estimator: AdaBoostRegressor(learning_rate=0.1, random_state=0)
# With 33.936% train accuracy
# With 25.346% test accuracy
# Dummy model: GaussianProcessRegressor()
# With 100.0% train accuracy
# With -163.742% test accuracy
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# Best estimator: GaussianProcessRegressor(alpha=0.05)
# With 97.431% train accuracy
# With -163.204% test accuracy
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Dummy model: MLPRegressor()
# With 48.052% train accuracy
# With 36.344% test accuracy
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best estimator: MLPRegressor(batch_size=100, hidden_layer_sizes=(50,), learning_rate_init=0.01,
#              max_iter=1000, random_state=0, solver='sgd')
# With 53.756% train accuracy
# With 27.2% test accuracy

# %% [markdown]
# # 2.0 Communities and Crime Dataset

# %%
# Load the data and split into features and targets, X and y
data = np.loadtxt("./data/communities.data", usecols=np.r_[0:1, 4:30,31:101,127:128], delimiter = ',')
X = data[:,:-1]
y = data[:,-1:].astype(np.float64).reshape(1994,)

X_trn, X_tst, y_trn, y_tst = preprocess(X,y)

train_all_regressors(X_trn,y_trn,X_tst,y_tst)
# Out:
# Dummy model: LinearRegression()
# With 70.721% train accuracy
# With 63.757% test accuracy
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# Best estimator: LinearRegression(n_jobs=0.0001)
# With 70.721% train accuracy
# With 63.757% test accuracy
# Dummy model: SVR()
# With 85.701% train accuracy
# With 58.057% test accuracy
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# Best estimator: SVR(gamma=0.001)
# With 71.071% train accuracy
# With 65.042% test accuracy
# Dummy model: DecisionTreeRegressor()
# With 100.0% train accuracy
# With 23.743% test accuracy
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# Best estimator: DecisionTreeRegressor(max_depth=5, min_samples_leaf=50, random_state=0)
# With 65.372% train accuracy
# With 57.346% test accuracy
# Dummy model: RandomForestRegressor()
# With 95.16% train accuracy
# With 62.32% test accuracy
# Fitting 3 folds for each of 56 candidates, totalling 168 fits
# Best estimator: RandomForestRegressor(max_depth=25, n_estimators=1000, random_state=0)
# With 95.36% train accuracy
# With 63.987% test accuracy
# Dummy model: KNeighborsRegressor()
# With 73.883% train accuracy
# With 60.541% test accuracy
# Fitting 3 folds for each of 45 candidates, totalling 135 fits
# Best estimator: KNeighborsRegressor(metric='manhattan', n_neighbors=9)
# With 70.06% train accuracy
# With 60.983% test accuracy
# Dummy model: AdaBoostRegressor()
# With 58.54% train accuracy
# With 44.567% test accuracy
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best estimator: AdaBoostRegressor(learning_rate=0.1, random_state=0)
# With 70.828% train accuracy
# With 61.189% test accuracy
# Dummy model: GaussianProcessRegressor()
# With 100.0% train accuracy
# With -101.787% test accuracy
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# Best estimator: GaussianProcessRegressor(alpha=0.05)
# With 99.534% train accuracy
# With -101.788% test accuracy
# Dummy model: MLPRegressor()
# With 90.878% train accuracy
# With 19.511% test accuracy
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best estimator: MLPRegressor(batch_size=100, hidden_layer_sizes=(), learning_rate_init=0.01,
#              max_iter=1000, random_state=0, solver='sgd')
# With 67.437% train accuracy
# With 59.712% test accuracy

# %% [markdown]
# # 3.0 QSAR aquatic toxicity Dataset

# %%
# Load the data and split into features and targets, X and y
df = pd.read_csv("./data/qsar_aquatic_toxicity.csv", delimiter = ';')
data = df.to_numpy()
X = np.delete(data,7,1)
y = data[:,7:8].astype(np.int32).reshape(545,)

X_trn, X_tst, y_trn, y_tst = preprocess(X,y)

train_all_regressors(X_trn,y_trn,X_tst,y_tst)
# Out:
# Dummy model: LinearRegression()
# With 25.227% train accuracy
# With 31.48% test accuracy
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# Best estimator: LinearRegression(n_jobs=0.0001)
# With 25.227% train accuracy
# With 31.48% test accuracy
# Dummy model: SVR()
# With 48.317% train accuracy
# With 11.477% test accuracy
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# Best estimator: SVR(C=10.0, gamma=1.0)
# With 98.173% train accuracy
# With 14.45% test accuracy
# Dummy model: DecisionTreeRegressor()
# With 100.0% train accuracy
# With 31.863% test accuracy
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# Best estimator: DecisionTreeRegressor(max_depth=5, min_samples_leaf=25, random_state=0)
# With 37.794% train accuracy
# With 18.803% test accuracy
# Dummy model: RandomForestRegressor()
# With 90.502% train accuracy
# With 31.351% test accuracy
# Fitting 3 folds for each of 56 candidates, totalling 168 fits
# Best estimator: RandomForestRegressor(max_depth=25, n_estimators=50, random_state=0)
# With 88.488% train accuracy
# With 30.433% test accuracy
# Dummy model: KNeighborsRegressor()
# With 47.962% train accuracy
# With 21.155% test accuracy
# Fitting 3 folds for each of 45 candidates, totalling 135 fits
# Best estimator: KNeighborsRegressor(metric='manhattan', n_neighbors=15)
# With 32.511% train accuracy
# With 18.689% test accuracy
# Dummy model: AdaBoostRegressor()
# With 36.869% train accuracy
# With 11.807% test accuracy
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best estimator: AdaBoostRegressor(learning_rate=0.5, n_estimators=5, random_state=0)
# With 51.069% train accuracy
# With 14.753% test accuracy
# Dummy model: GaussianProcessRegressor()
# With 100.0% train accuracy
# With 0.575% test accuracy
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# Best estimator: GaussianProcessRegressor(alpha=0.3)
# With 90.044% train accuracy
# With 8.305% test accuracy
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Dummy model: MLPRegressor()
# With 66.319% train accuracy
# With 38.869% test accuracy
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best estimator: MLPRegressor(batch_size=100, hidden_layer_sizes=(), learning_rate_init=0.01,
#              max_iter=1000, random_state=0)
# With 25.165% train accuracy
# With 31.085% test accuracy

# %% [markdown]
# ## 4.0 Facebook Metrics Dataset

# %%
# Load the data and split into features and targets, X and y
fb = pd.read_csv("./data/dataset_Facebook.csv", delimiter = ';')
fb_data = fb.to_numpy()

# Assign 'Photo' a value 1, and 'Status' a value 0
for i in range(500):
    if fb_data[i][1] == 'Photo':
        fb_data[i][1] = 1
    else: 
        fb_data[i][1] = 0
        
fb_data = np.delete(fb_data,np.r_[0:1,3:7,15:18],axis=1)
X = fb_data[:,1:]
y = fb_data[:,0:1].astype(np.int32).reshape(500,)

X_trn, X_tst, y_trn, y_tst = preprocess(X,y)

train_all_regressors(X_trn,y_trn,X_tst,y_tst)
# Out:
# Dummy model: LinearRegression()
# With 31.506% train accuracy
# With 20.139% test accuracy
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# Best estimator: LinearRegression(n_jobs=0.0001)
# With 31.506% train accuracy
# With 20.139% test accuracy
# Dummy model: SVR()
# With 60.609% train accuracy
# With 47.144% test accuracy
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# Best estimator: SVR(gamma=0.1)
# With 60.609% train accuracy
# With 47.144% test accuracy
# Dummy model: DecisionTreeRegressor()
# With 100.0% train accuracy
# With 30.556% test accuracy
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# Best estimator: DecisionTreeRegressor(max_depth=5, min_samples_leaf=25, random_state=0)
# With 51.417% train accuracy
# With 25.986% test accuracy
# Dummy model: RandomForestRegressor()
# With 93.948% train accuracy
# With 43.087% test accuracy
# Fitting 3 folds for each of 56 candidates, totalling 168 fits
# Best estimator: RandomForestRegressor(max_depth=25, n_estimators=1000, random_state=0)
# With 94.61% train accuracy
# With 45.776% test accuracy
# Dummy model: KNeighborsRegressor()
# With 69.76% train accuracy
# With 62.302% test accuracy
# Fitting 3 folds for each of 45 candidates, totalling 135 fits
# Best estimator: KNeighborsRegressor(metric='euclidean', n_neighbors=7)
# With 65.571% train accuracy
# With 61.633% test accuracy
# Dummy model: AdaBoostRegressor()
# With 53.872% train accuracy
# With 42.343% test accuracy
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best estimator: AdaBoostRegressor(learning_rate=1.5, n_estimators=25, random_state=0)
# With 70.278% train accuracy
# With 41.545% test accuracy
# Dummy model: GaussianProcessRegressor()
# With 100.0% train accuracy
# With -59894.071% test accuracy
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# Best estimator: GaussianProcessRegressor(alpha=0.05)
# With 88.045% train accuracy
# With 17.807% test accuracy
# Dummy model: MLPRegressor()
# With 58.472% train accuracy
# With 47.221% test accuracy
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best estimator: MLPRegressor(batch_size=100, hidden_layer_sizes=(10, 10),
#              learning_rate_init=0.01, max_iter=1000, random_state=0)
# With 83.835% train accuracy
# With -17.076% test accuracy

# %% [markdown]
# ## 5.0 Bike Sharing Dataset

# %%
# Load the data and split into features and targets, X and y
df_bike = pd.read_csv('./data/hour.csv', sep=',')
# Convert date time to integer
df_bike['dteday'] = pd.to_datetime(df_bike['dteday']).apply(lambda x : x.toordinal())
sl = slice(1000)
df_bike = (df_bike[sl])
data = df_bike.to_numpy()
X = data[:,:-1]
y = data[:,-1]

X_trn, X_tst, y_trn, y_tst = preprocess(X,y)

train_all_regressors(X_trn,y_trn,X_tst,y_tst)
# Out:
# Dummy model: LinearRegression()
# With 100.0% train accuracy
# With 99.796% test accuracy
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# Best estimator: LinearRegression(n_jobs=0.0001)
# With 100.0% train accuracy
# With 99.796% test accuracy
# Dummy model: SVR()
# With 50.925% train accuracy
# With 49.369% test accuracy
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# Best estimator: SVR(C=1000.0, gamma=0.001)
# With 99.999% train accuracy
# With 99.803% test accuracy
# Dummy model: DecisionTreeRegressor()
# With 100.0% train accuracy
# With 99.405% test accuracy
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# Best estimator: DecisionTreeRegressor(max_depth=10, min_samples_leaf=5, random_state=0)
# With 99.724% train accuracy
# With 99.081% test accuracy
# Dummy model: RandomForestRegressor()
# With 99.94% train accuracy
# With 99.493% test accuracy
# Fitting 3 folds for each of 56 candidates, totalling 168 fits
# Best estimator: RandomForestRegressor(max_depth=25, n_estimators=1000, random_state=0)
# With 99.948% train accuracy
# With 99.495% test accuracy
# Dummy model: KNeighborsRegressor()
# With 91.139% train accuracy
# With 88.304% test accuracy
# Fitting 3 folds for each of 45 candidates, totalling 135 fits
# Best estimator: KNeighborsRegressor(metric='euclidean')
# With 91.139% train accuracy
# With 88.304% test accuracy
# Dummy model: AdaBoostRegressor()
# With 98.394% train accuracy
# With 97.775% test accuracy
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best estimator: AdaBoostRegressor(learning_rate=2.0, n_estimators=85, random_state=0)
# With 98.754% train accuracy
# With 98.222% test accuracy
# Dummy model: GaussianProcessRegressor()
# With 100.0% train accuracy
# With 55.499% test accuracy
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# Best estimator: GaussianProcessRegressor(alpha=0.05)
# With 99.822% train accuracy
# With 53.415% test accuracy
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Dummy model: MLPRegressor()
# With 91.586% train accuracy
# With 91.596% test accuracy
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_base.py:170: RuntimeWarning: overflow encountered in square
#   return ((y_true - y_pred) ** 2).mean() / 2
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_base.py:170: RuntimeWarning: overflow encountered in square
#   return ((y_true - y_pred) ** 2).mean() / 2
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_base.py:170: RuntimeWarning: overflow encountered in square
#   return ((y_true - y_pred) ** 2).mean() / 2
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_base.py:170: RuntimeWarning: overflow encountered in square
#   return ((y_true - y_pred) ** 2).mean() / 2
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_base.py:170: RuntimeWarning: overflow encountered in square
#   return ((y_true - y_pred) ** 2).mean() / 2
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_base.py:170: RuntimeWarning: overflow encountered in square
#   return ((y_true - y_pred) ** 2).mean() / 2
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_base.py:170: RuntimeWarning: overflow encountered in square
#   return ((y_true - y_pred) ** 2).mean() / 2
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_base.py:170: RuntimeWarning: overflow encountered in square
#   return ((y_true - y_pred) ** 2).mean() / 2
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_base.py:170: RuntimeWarning: overflow encountered in square
#   return ((y_true - y_pred) ** 2).mean() / 2
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the test scores are non-finite: [   0.99999983    0.82964323           nan    0.99971157           nan
#     0.99957334           nan    0.99961544 -390.13293565    0.99970234
#            nan    0.99901585           nan    0.99952198           nan
#     0.99950686]
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the train scores are non-finite: [   0.99999985    0.84198989           nan    0.99992116           nan
#     0.99994137           nan    0.999955   -385.70132596    0.99991994
#            nan    0.99978086           nan    0.99990782           nan
#     0.99987614]
#   warnings.warn(
# Best estimator: MLPRegressor(batch_size=100, hidden_layer_sizes=(), learning_rate_init=0.01,
#              max_iter=1000, random_state=0, solver='sgd')
# With 100.0% train accuracy
# With 99.796% test accuracy

# %% [markdown]
# ## 6.0 Student Performance Dataset

# %%
# Load the data and split into features and targets, X and y
df = pd.read_csv("./data/student-por.csv", sep = ';')
col_objs = df.select_dtypes(['object']).columns
encoder = LabelEncoder()

for col in col_objs:
    df[col] = encoder.fit_transform(df[col])

data = df.to_numpy()
X = data[:,:-1]
y = data[:,-1]

X_trn, X_tst, y_trn, y_tst = preprocess(X,y)

train_all_regressors(X_trn,y_trn,X_tst,y_tst)
# Out:
# Dummy model: LinearRegression()
# With 86.642% train accuracy
# With 82.299% test accuracy
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# Best estimator: LinearRegression(n_jobs=0.0001)
# With 86.642% train accuracy
# With 82.299% test accuracy
# Dummy model: SVR()
# With 79.624% train accuracy
# With 70.472% test accuracy
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# Best estimator: SVR(C=100.0, gamma=0.001)
# With 87.534% train accuracy
# With 83.977% test accuracy
# Dummy model: DecisionTreeRegressor()
# With 100.0% train accuracy
# With 69.865% test accuracy
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# Best estimator: DecisionTreeRegressor(max_depth=5, min_samples_leaf=10, random_state=0)
# With 85.399% train accuracy
# With 74.024% test accuracy
# Dummy model: RandomForestRegressor()
# With 97.841% train accuracy
# With 80.538% test accuracy
# Fitting 3 folds for each of 56 candidates, totalling 168 fits
# Best estimator: RandomForestRegressor(max_depth=10, n_estimators=500, random_state=0)
# With 97.844% train accuracy
# With 80.027% test accuracy
# Dummy model: KNeighborsRegressor()
# With 71.808% train accuracy
# With 57.753% test accuracy
# Fitting 3 folds for each of 45 candidates, totalling 135 fits
# Best estimator: KNeighborsRegressor(metric='euclidean', n_neighbors=7)
# With 70.844% train accuracy
# With 57.879% test accuracy
# Dummy model: AdaBoostRegressor()
# With 91.537% train accuracy
# With 74.876% test accuracy
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best estimator: AdaBoostRegressor(learning_rate=0.1, n_estimators=5, random_state=0)
# With 86.197% train accuracy
# With 73.005% test accuracy
# Dummy model: GaussianProcessRegressor()
# With 100.0% train accuracy
# With -1449.126% test accuracy
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# Best estimator: GaussianProcessRegressor(alpha=0.05)
# With 96.791% train accuracy
# With -1449.471% test accuracy
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Dummy model: MLPRegressor()
# With 85.302% train accuracy
# With 60.327% test accuracy
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best estimator: MLPRegressor(batch_size=100, hidden_layer_sizes=(), learning_rate_init=0.01,
#              max_iter=1000, random_state=0)
# With 86.63% train accuracy
# With 82.214% test accuracy

# %% [markdown]
# ## 7.0 Concrete Compressive Strength Dataset

# %%
# Load the data and split into features and targets, X and y
data = load_xls_file(filename = './data/Concrete_Data.xls', skip_rows=1,skip_cols=0)
X, y = split_data(data,8,1)

X_trn, X_tst, y_trn, y_tst = preprocess(X,y)

train_all_regressors(X_trn,y_trn,X_tst,y_tst)
# Out:
# Dummy model: LinearRegression()
# With 60.802% train accuracy
# With 63.733% test accuracy
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# Best estimator: LinearRegression(n_jobs=0.0001)
# With 60.802% train accuracy
# With 63.733% test accuracy
# Dummy model: SVR()
# With 65.01% train accuracy
# With 63.853% test accuracy
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# Best estimator: SVR(C=100.0, gamma=0.1)
# With 93.01% train accuracy
# With 84.324% test accuracy
# Dummy model: DecisionTreeRegressor()
# With 99.591% train accuracy
# With 75.649% test accuracy
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# Best estimator: DecisionTreeRegressor(max_depth=25, min_samples_leaf=5, random_state=0)
# With 93.69% train accuracy
# With 76.488% test accuracy
# Dummy model: RandomForestRegressor()
# With 98.371% train accuracy
# With 88.076% test accuracy
# Fitting 3 folds for each of 56 candidates, totalling 168 fits
# Best estimator: RandomForestRegressor(max_depth=25, n_estimators=1000, random_state=0)
# With 98.435% train accuracy
# With 88.019% test accuracy
# Dummy model: KNeighborsRegressor()
# With 82.034% train accuracy
# With 65.969% test accuracy
# Fitting 3 folds for each of 45 candidates, totalling 135 fits
# Best estimator: KNeighborsRegressor(metric='euclidean')
# With 82.034% train accuracy
# With 65.969% test accuracy
# Dummy model: AdaBoostRegressor()
# With 82.508% train accuracy
# With 75.628% test accuracy
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best estimator: AdaBoostRegressor(n_estimators=100, random_state=0)
# With 82.947% train accuracy
# With 77.3% test accuracy
# Dummy model: GaussianProcessRegressor()
# With 99.591% train accuracy
# With -713.854% test accuracy
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# Best estimator: GaussianProcessRegressor(alpha=0.05)
# With 97.623% train accuracy
# With 79.786% test accuracy
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Dummy model: MLPRegressor()
# With 52.079% train accuracy
# With 49.992% test accuracy
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_base.py:170: RuntimeWarning: overflow encountered in square
#   return ((y_true - y_pred) ** 2).mean() / 2
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the test scores are non-finite: [0.58950784 0.57492962 0.69568105 0.85030949 0.82943241 0.86573021
#  0.87610138 0.88780053 0.28520677 0.85111227        nan 0.86751926
#         nan 0.87599036        nan 0.87464077]
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the train scores are non-finite: [0.6103993  0.59464198 0.74922892 0.89338871 0.86793678 0.91543659
#  0.93429105 0.95383099 0.31843968 0.90984283        nan 0.93701004
#         nan 0.93880461        nan 0.93608524]
#   warnings.warn(
# Best estimator: MLPRegressor(batch_size=100, learning_rate_init=0.01, max_iter=1000,
#              random_state=0)
# With 95.063% train accuracy
# With 85.063% test accuracy

# %% [markdown]
# ## 8.0 SGEMM GPU kernel performance Dataset

# %%
# Load the data and split into features and targets, X and y
data_sgemm = np.loadtxt('./data/sgemm_product.csv',dtype='float64',delimiter=',',skiprows=1)
sl = slice(1000)
data_sgemm = (data_sgemm[sl])
X = data_sgemm[:,:14]
# Since we have 4 target columns for 4 different runs, we compute the average of those 4 columns to use as our target
y_temp = data_sgemm[:,14:18]
y = np.average(y_temp, axis=1)

X_trn, X_tst, y_trn, y_tst = preprocess(X,y)

train_all_regressors(X_trn,y_trn,X_tst,y_tst)
# Out:
# Dummy model: LinearRegression()
# With 76.66% train accuracy
# With 76.622% test accuracy
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# Best estimator: LinearRegression(n_jobs=0.0001)
# With 76.66% train accuracy
# With 76.622% test accuracy
# Dummy model: SVR()
# With 62.05% train accuracy
# With 55.023% test accuracy
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# Best estimator: SVR(C=1000.0, gamma=0.1)
# With 99.998% train accuracy
# With 98.179% test accuracy
# Dummy model: DecisionTreeRegressor()
# With 100.0% train accuracy
# With 99.731% test accuracy
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# Best estimator: DecisionTreeRegressor(max_depth=10, min_samples_leaf=5, random_state=0)
# With 98.546% train accuracy
# With 97.003% test accuracy
# Dummy model: RandomForestRegressor()
# With 99.935% train accuracy
# With 99.565% test accuracy
# Fitting 3 folds for each of 56 candidates, totalling 168 fits
# Best estimator: RandomForestRegressor(max_depth=10, n_estimators=1000, random_state=0)
# With 99.917% train accuracy
# With 99.55% test accuracy
# Dummy model: KNeighborsRegressor()
# With 92.217% train accuracy
# With 86.726% test accuracy
# Fitting 3 folds for each of 45 candidates, totalling 135 fits
# Best estimator: KNeighborsRegressor(metric='euclidean', n_neighbors=3)
# With 91.459% train accuracy
# With 87.652% test accuracy
# Dummy model: AdaBoostRegressor()
# With 80.161% train accuracy
# With 80.77% test accuracy
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best estimator: AdaBoostRegressor(learning_rate=2.0, n_estimators=100, random_state=0)
# With 81.85% train accuracy
# With 83.292% test accuracy
# Dummy model: GaussianProcessRegressor()
# With 100.0% train accuracy
# With -204.462% test accuracy
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# Best estimator: GaussianProcessRegressor(alpha=0.05)
# With 99.12% train accuracy
# With -222.057% test accuracy
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Dummy model: MLPRegressor()
# With 82.956% train accuracy
# With 81.834% test accuracy
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_base.py:170: RuntimeWarning: overflow encountered in square
#   return ((y_true - y_pred) ** 2).mean() / 2
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_base.py:170: RuntimeWarning: overflow encountered in square
#   return ((y_true - y_pred) ** 2).mean() / 2
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_base.py:170: RuntimeWarning: overflow encountered in square
#   return ((y_true - y_pred) ** 2).mean() / 2
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_base.py:170: RuntimeWarning: overflow encountered in square
#   return ((y_true - y_pred) ** 2).mean() / 2
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_scorer.py", line 397, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the test scores are non-finite: [ 7.56365802e-01 -2.84638504e+00  6.35442207e-01  9.47919811e-01
#              nan  9.77397170e-01             nan  9.80179921e-01
#  -6.80062739e+22  9.49120176e-01 -9.99234601e+04  9.77124886e-01
#              nan  9.79854420e-01             nan  9.80539551e-01]
#   warnings.warn(
# c:\users\asinn\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the train scores are non-finite: [ 7.68163464e-01 -2.60526505e+00  6.46751817e-01  9.62344246e-01
#              nan  9.98117162e-01             nan  9.99863112e-01
#  -6.57098923e+22  9.81022395e-01 -1.00293666e+05  9.99128763e-01
#              nan  9.99268453e-01             nan  9.99626964e-01]
#   warnings.warn(
# Best estimator: MLPRegressor(batch_size=100, hidden_layer_sizes=(100, 100),
#              learning_rate_init=0.01, max_iter=1000, random_state=0)
# With 99.902% train accuracy
# With 97.064% test accuracy
